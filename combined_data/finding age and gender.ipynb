# %%
import pandas as pd

# %%
ls
# Out:
# Final_Filter_Merge_10014x251_Nafi.csv  finding age and gender.ipynb
# Final_Filter_Merge_16256x191_Nafi.csv

# %%
df = pd.read_csv('Final_Filter_Merge_10014x251_Nafi.csv')

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'PATNO',
#  'EVENT_ID',
#  'NHY',
#  'CLASS',
#  'NUPSOURC',
#  'NP1COG',
#  'NP1HALL',
#  'NP1DPRS',
#  'NP1ANXS',
#  'NP1APAT',
#  'NP1DDS',
#  'NP1RTOT',
#  'NP1SLPN',
#  'NP1SLPD',
#  'NP1PAIN',
#  'NP1URIN',
#  'NP1CNST',
#  'NP1LTHD',
#  'NP1FATG',
#  'NP1PTOT',
#  'NP2SPCH',
#  'NP2SALV',
#  'NP2SWAL',
#  'NP2EAT',
#  'NP2DRES',
#  'NP2HYGN',
#  'NP2HWRT',
#  'NP2HOBB',
#  'NP2TURN',
#  'NP2TRMR',
#  'NP2RISE',
#  'NP2WALK',
#  'NP2FREZ',
#  'NP2PTOT',
#  'PDTRTMNT',
#  'PDMEDYN',
#  'DBSYN',
#  'NP3SPCH',
#  'NP3FACXP',
#  'NP3RIGN',
#  'NP3RIGRU',
#  'NP3RIGLU',
#  'NP3RIGRL',
#  'NP3RIGLL',
#  'NP3FTAPR',
#  'NP3FTAPL',
#  'NP3HMOVR',
#  'NP3HMOVL',
#  'NP3PRSPR',
#  'NP3PRSPL',
#  'NP3TTAPR',
#  'NP3TTAPL',
#  'NP3LGAGR',
#  'NP3LGAGL',
#  'NP3RISNG',
#  'NP3GAIT',
#  'NP3FRZGT',
#  'NP3PSTBL',
#  'NP3POSTR',
#  'NP3BRADY',
#  'NP3PTRMR',
#  'NP3PTRML',
#  'NP3KTRMR',
#  'NP3KTRML',
#  'NP3RTARU',
#  'NP3RTALU',
#  'NP3RTARL',
#  'NP3RTALL',
# ...

# %%
for column in df.columns.tolist():
    column = column.lower()
    if 'age' in column:
        print(column)
    elif 'gender' in column:
        print(column)

print('test')
# Out:
# test

# %%
s = 'STring'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tolower(s)
#
# NameError: name 'tolower' is not defined
