# %%
import pandas as pd
import numpy as np

# %%
dict_df = pd.read_csv('Data_Dictionary_-__Annotated__24May2024.csv')
final_merge_df = pd.read_csv('Final_Filter_Merge_10014x251_Nafi.csv')

# %%
rel_cols = final_merge_df.iloc[:,5:].columns.tolist() # relevant columns

# %%
rel_cols # ommited CLASS and NHY columns
# Out:
# ['NUPSOURC',
#  'NP1COG',
#  'NP1HALL',
#  'NP1DPRS',
#  'NP1ANXS',
#  'NP1APAT',
#  'NP1DDS',
#  'NP1RTOT',
#  'NP1SLPN',
#  'NP1SLPD',
#  'NP1PAIN',
#  'NP1URIN',
#  'NP1CNST',
#  'NP1LTHD',
#  'NP1FATG',
#  'NP1PTOT',
#  'NP2SPCH',
#  'NP2SALV',
#  'NP2SWAL',
#  'NP2EAT',
#  'NP2DRES',
#  'NP2HYGN',
#  'NP2HWRT',
#  'NP2HOBB',
#  'NP2TURN',
#  'NP2TRMR',
#  'NP2RISE',
#  'NP2WALK',
#  'NP2FREZ',
#  'NP2PTOT',
#  'PDTRTMNT',
#  'PDMEDYN',
#  'DBSYN',
#  'NP3SPCH',
#  'NP3FACXP',
#  'NP3RIGN',
#  'NP3RIGRU',
#  'NP3RIGLU',
#  'NP3RIGRL',
#  'NP3RIGLL',
#  'NP3FTAPR',
#  'NP3FTAPL',
#  'NP3HMOVR',
#  'NP3HMOVL',
#  'NP3PRSPR',
#  'NP3PRSPL',
#  'NP3TTAPR',
#  'NP3TTAPL',
#  'NP3LGAGR',
#  'NP3LGAGL',
#  'NP3RISNG',
#  'NP3GAIT',
#  'NP3FRZGT',
#  'NP3PSTBL',
#  'NP3POSTR',
#  'NP3BRADY',
#  'NP3PTRMR',
#  'NP3PTRML',
#  'NP3KTRMR',
#  'NP3KTRML',
#  'NP3RTARU',
#  'NP3RTALU',
#  'NP3RTARL',
#  'NP3RTALL',
#  'NP3RTALJ',
#  'NP3RTCON',
#  'NP3TOT',
#  'DYSKPRES',
#  'MSEADLG',
# ...

# %%
len(rel_cols)
# Out:
# 246

# %%
dict_df.set_index('ITM_NAME', inplace=True)

# %%
my_dict = dict_df.loc[rel_cols, 'DSCR']

# %%
my_dict.shape
# Out:
# (254, 1)

# %%
pd.set_option('display.max_rows', 300)

# %%
my_dict = pd.DataFrame(my_dict)

# %%
origin_df = pd.read_csv('merged_files_with_origin.csv')
# Out:
# /var/folders/k1/8dq9mz1519b8yr7hw5g0kpm00000gn/T/ipykernel_38154/4121164634.py:1: DtypeWarning: Columns (0,3,4,13,14,15,16,17,27,28,29,30,31,47,48,49,50,51,53,62,65,66,67,68,69,107,108,109,110,111,128,129,130,188,189,190,191,193,195,202,209,210,211,212,213,214,216,217,218,219,220,229,230,231,232,233,242,243,244,245,246,259,260,261,262,263,300,301,302,303,304,313,314,315,316,317,325,326,327,328,329,330,332,333,334,335,336,346,347,348,349,350,366,367,368,369,370,384,385,386,387,388,413,414,415,416,417,421,422,423,424,425,429,430,431,432,433,440,441,442,443,444,473,474,475,476,477,482,483,484,485,486,492,493,494,495,496,511,512,513,514,515,538,539,540,541,542,568,572,574,576,578,579,580,581,582,583,624,625,626,627,628,634,635,636,637,638,645,646,647,648,649,734,735,736,737,738) have mixed types. Specify dtype option on import or set low_memory=False.
#   origin_df = pd.read_csv('merged_files_with_origin.csv')

# %%
my_dict.shape
# Out:
# (254, 1)

# %%
my_dict
# Out:
#                                                             DSCR
# ITM_NAME
# NUPSOURC                           Primary Source of Information
# NUPSOURC                           Primary Source of Information
# NUPSOURC                           Primary Source of Information
# NP1COG                                      COGNITIVE IMPAIRMENT
# NP1HALL                             HALLUCINATIONS AND PSYCHOSIS
# NP1DPRS                                          DEPRESSED MOODS
# NP1ANXS                                             ANXIOUS MOOD
# NP1APAT                                                   APATHY
# NP1DDS                  FEATURES-DOPAMINE DYSREGULATION SYNDROME
# NP1RTOT           MDS-UPDRS Part I (Rater Completed) Total Score
# NP1SLPN                                   SLEEP PROBLEMS (NIGHT)
# NP1SLPD                                       DAYTIME SLEEPINESS
# NP1PAIN                                PAIN AND OTHER SENSATIONS
# ...

# %%
def easier(items):
    i = 1
    for item in items:
        print(i)
        i+=1
        bool_series = origin_df.columns.str.contains(item)
        index = np.where(bool_series)[0]
        index = index[0]
        origin_name = origin_df.columns[index]
        print(f"{item}: {origin_name}\n")

# %%
easier(my_dict.index.tolist())
# Out:
# 1
# NUPSOURC: MDS-UPDRS_Part_I_24May2024_NUPSOURC
#
# 2
# NUPSOURC: MDS-UPDRS_Part_I_24May2024_NUPSOURC
#
# 3
# NUPSOURC: MDS-UPDRS_Part_I_24May2024_NUPSOURC
#
# 4
# NP1COG: MDS-UPDRS_Part_I_24May2024_NP1COG
#
# 5
# NP1HALL: MDS-UPDRS_Part_I_24May2024_NP1HALL
#
# 6
# NP1DPRS: MDS-UPDRS_Part_I_24May2024_NP1DPRS
#
# 7
# NP1ANXS: MDS-UPDRS_Part_I_24May2024_NP1ANXS
#
# 8
# NP1APAT: MDS-UPDRS_Part_I_24May2024_NP1APAT
#
# 9
# NP1DDS: MDS-UPDRS_Part_I_24May2024_NP1DDS
#
# 10
# NP1RTOT: MDS-UPDRS_Part_I_24May2024_NP1RTOT
#
# 11
# NP1SLPN: MDS-UPDRS_Part_I_Patient_Questionnaire_24May2024_NP1SLPN
#
# 12
# NP1SLPD: MDS-UPDRS_Part_I_Patient_Questionnaire_24May2024_NP1SLPD
#
# 13
# NP1PAIN: MDS-UPDRS_Part_I_Patient_Questionnaire_24May2024_NP1PAIN
#
# 14
# NP1URIN: MDS-UPDRS_Part_I_Patient_Questionnaire_24May2024_NP1URIN
#
# 15
# NP1CNST: MDS-UPDRS_Part_I_Patient_Questionnaire_24May2024_NP1CNST
#
# 16
# NP1LTHD: MDS-UPDRS_Part_I_Patient_Questionnaire_24May2024_NP1LTHD
#
# 17
# ...

# %%
helper_dict = {
    'NUPSOURC': 'self report',
    'NUPSOURC': 'self report',
    'NUPSOURC': 'self report',
    'NP1COG': 'self report',
    'NP1HALL': 'self report',
    'NP1DPRS': 'self report',
    'NP1ANXS': 'self report',
    'NP1APAT': 'self report',
    'NP1DDS': 'self report',
    'NP1RTOT': 'self report',
    'NP2SPCH': 'self report',
    'NP2SALV': 'self report',
    'NP2SWAL': 'self report',
    'NP2EAT': 'self report',
    'NP2DRES': 'self report',
    'NP2HYGN': 'self report',
    'NP2HWRT': 'self report',
    'NP2HOBB': 'self report',
    'NP2TURN': 'self report',
    'NP2TRMR': 'self report',
    'NP2RISE': 'self report',
    'NP2WALK': 'self report',
    'NP2FREZ': 'self report',
    'NP2PTOT': 'self report',
    'PDTRTMNT': 'motor',
    'PDMEDYN': 'motor',
    'PDMEDYN': 'motor',
    'PDMEDYN': 'motor',
    'DBSYN': 'motor',
    'NP3SPCH': 'motor',
    'NP3FACXP': 'motor',
    'NP3RIGN': 'motor',
    'NP3RIGRU': 'motor',
    'NP3RIGLU': 'motor',
    'NP3RIGRL': 'motor',
    'NP3RIGLL': 'motor',
    'NP3FTAPR': 'motor',
    'NP3FTAPL': 'motor',
    'NP3HMOVR': 'motor',
    'NP3HMOVL': 'motor',
    'NP3PRSPR': 'motor',
    'NP3PRSPL': 'motor',
    'NP3TTAPR': 'motor',
    'NP3TTAPL': 'motor',
    'NP3LGAGR': 'motor',
    'NP3LGAGL': 'motor',
    'NP3RISNG': 'motor',
    'NP3GAIT': 'motor',
    'NP3FRZGT': 'motor',
    'NP3PSTBL': 'motor',
    'NP3POSTR': 'motor',
    'NP3BRADY': 'motor',
    'NP3PTRMR': 'motor',
    'NP3PTRML': 'motor',
    'NP3KTRMR': 'motor',
    'NP3KTRML': 'motor',
    'NP3RTARU': 'motor',
    'NP3RTALU': 'motor',
    'NP3RTARL': 'motor',
    'NP3RTALL': 'motor',
    'NP3RTALJ': 'motor',
    'NP3RTCON': 'motor',
    'NP3TOT': 'motor',
    'DYSKPRES': 'motor',
    'MSEADLG': 'motor',
    'BENTONVERSION': 'non motor',
    'PTCGBOTH': 'non motor',
    'PTCGBOTH': 'non motor',
    'PTCGBOTH': 'non motor',
    'PTCGBOTH': 'non motor',
    'PTCGBOTH': 'non motor',
    'COGDECLN': 'non motor',
    'COGSTATE': 'non motor',
    'COGDXCL': 'non motor',
    'RVWNPSY': 'non motor',
    'ESS1': 'non motor',
    'ESS2': 'non motor',
    'ESS3': 'non motor',
    'ESS4': 'non motor',
    'ESS5': 'non motor',
    'ESS6': 'non motor',
    'ESS7': 'non motor',
    'ESS8': 'non motor',
    'GDSSATIS': 'self report',
    'GDSDROPD': 'self report',
    'GDSEMPTY': 'self report',
    'GDSBORED': 'self report',
    'GDSGSPIR': 'self report',
    'GDSAFRAD': 'self report',
    'GDSHAPPY': 'self report',
    'GDSHLPLS': 'self report',
    'GDSHOME': 'self report',
    'GDSMEMRY': 'self report',
    'GDSALIVE': 'self report',
    'GDSWRTLS': 'self report',
    'GDSENRGY': 'self report',
    'GDSHOPLS': 'self report',
    'GDSBETER': 'self report',
    'HVLTRT1': 'non motor',
    'HVLTRT2': 'non motor',
    'HVLTRT3': 'non motor',
    'HVLTRDLY': 'non motor',
    'HVLTREC': 'non motor',
    'HVLTFPRL': 'non motor',
    'HVLTFPUN': 'non motor',
    'HVLTVRSN': 'non motor',
    'LNS1A': 'non motor',
    'LNS1B': 'non motor',
    'LNS1C': 'non motor',
    'LNS2A': 'non motor',
    'LNS2B': 'non motor',
    'LNS2C': 'non motor',
    'LNS3A': 'non motor',
    'LNS3B': 'non motor',
    'LNS3C': 'non motor',
    'VLTANIM': 'non motor',
    'MCAALTTM': 'non motor',
    'MCACUBE': 'non motor',
    'MCACLCKC': 'non motor',
    'MCACLCKN': 'non motor',
    'MCACLCKH': 'non motor',
    'MCALION': 'non motor',
    'MCARHINO': 'non motor',
    'MCACAMEL': 'non motor',
    'MCAFDS': 'non motor',
    'MCABDS': 'non motor',
    'MCAVIGIL': 'non motor',
    'MCASER7': 'non motor',
    'MCASNTNC': 'non motor',
    'MCAVFNUM': 'non motor',
    'MCAVF': 'non motor',
    'MCAABSTR': 'non motor',
    'MCAREC1': 'non motor',
    'MCAREC2': 'non motor',
    'MCAREC3': 'non motor',
    'MCAREC4': 'non motor',
    'MCAREC5': 'non motor',
    'MCADATE': 'non motor',
    'MCAMONTH': 'non motor',
    'MCAYR': 'non motor',
    'MCADAY': 'non motor',
    'MCAPLACE': 'non motor',
    'MCACITY': 'non motor',
    'PTINBOTH': 'self report',
    'TMGAMBLE': 'self report',
    'CNTRLGMB': 'self report',
    'TMSEX': 'self report',
    'CNTRLSEX': 'self report',
    'TMBUY': 'self report',
    'CNTRLBUY': 'self report',
    'TMEAT': 'self report',
    'CNTRLEAT': 'self report',
    'TMTORACT': 'self report',
    'TMTMTACT': 'self report',
    'TMTRWD': 'self report',
    'TMDISMED': 'self report',
    'CNTRLDSM': 'self report',
    'DRMVIVID': 'non motor',
    'DRMAGRAC': 'non motor',
    'DRMNOCTB': 'non motor',
    'SLPLMBMV': 'non motor',
    'SLPINJUR': 'non motor',
    'DRMVERBL': 'non motor',
    'DRMFIGHT': 'non motor',
    'DRMUMV': 'non motor',
    'DRMOBJFL': 'non motor',
    'MVAWAKEN': 'non motor',
    'DRMREMEM': 'non motor',
    'SLPDSTRB': 'non motor',
    'STROKE': 'non motor',
    'HETRA': 'non motor',
    'PARKISM': 'non motor',
    'RLS': 'self report',
    'NARCLPSY': 'non motor',
    'DEPRS': 'non motor',
    'EPILEPSY': 'non motor',
    'BRNINFM': 'non motor',
    'CNSOTH': 'non motor',
    'SCAU1': 'non motor',
    'SCAU2': 'non motor',
    'SCAU3': 'non motor',
    'SCAU4': 'non motor',
    'SCAU5': 'non motor',
    'SCAU6': 'non motor',
    'SCAU7': 'non motor',
    'SCAU8': 'non motor',
    'SCAU9': 'non motor',
    'SCAU10': 'non motor',
    'SCAU11': 'non motor',
    'SCAU12': 'non motor',
    'SCAU13': 'non motor',
    'SCAU14': 'non motor',
    'SCAU15': 'non motor',
    'SCAU16': 'non motor',
    'SCAU17': 'non motor',
    'SCAU18': 'non motor',
    'SCAU19': 'non motor',
    'SCAU20': 'non motor',
    'SCAU21': 'non motor',
    'SCAU26A': 'non motor',
    'SCAU26B': 'non motor',
    'SCAU26C': 'non motor',
    'SCAU26D': 'non motor',
    'STAIAD1': 'self report',
    'STAIAD2': 'self report',
    'STAIAD3': 'self report',
    'STAIAD4': 'self report',
    'STAIAD5': 'self report',
    'STAIAD6': 'self report',
    'STAIAD7': 'self report',
    'STAIAD8': 'self report',
    'STAIAD9': 'self report',
    'STAIAD10': 'self report',
    'STAIAD11': 'self report',
    'STAIAD12': 'self report',
    'STAIAD13': 'self report',
    'STAIAD14': 'self report',
    'STAIAD15': 'self report',
    'STAIAD16': 'self report',
    'STAIAD17': 'self report',
    'STAIAD18': 'self report',
    'STAIAD19': 'self report',
    'STAIAD20': 'self report',
    'STAIAD21': 'self report',
    'STAIAD22': 'self report',
    'STAIAD23': 'self report',
    'STAIAD24': 'self report',
    'STAIAD25': 'self report',
    'STAIAD26': 'self report',
    'STAIAD27': 'self report',
    'STAIAD28': 'self report',
    'STAIAD29': 'self report',
    'STAIAD30': 'self report',
    'STAIAD31': 'self report',
    'STAIAD32': 'self report',
    'STAIAD33': 'self report',
    'STAIAD34': 'self report',
    'STAIAD35': 'self report',
    'STAIAD36': 'self report',
    'STAIAD37': 'self report',
    'STAIAD38': 'self report',
    'STAIAD39': 'self report',
    'STAIAD40': 'self report',
    'SDMTOTAL': 'non motor',
    'SDMTVRSN': 'non motor'
    
}

# %%
len(helper_dict)
# Out:
# 237

# %%
origin_df
# Out:
#       MDS-UPDRS_Part_I_24May2024_REC_ID   PATNO EVENT_ID  \
# 0                             272451201    3000       BL
# 1                             338701901    3000      V04
# 2                             385008801    3000      V06
# 3                             437130601    3000      V08
# 4                             512466501    3000      V10
# ...                                 ...     ...      ...
# 30698                               NaN  324157       SC
# 30699                               NaN  324508       SC
# 30700                               NaN  325198       BL
# 30701                               NaN  325234       SC
# 30702                               NaN  339455       SC
#
#       MDS-UPDRS_Part_I_24May2024_PAG_NAME MDS-UPDRS_Part_I_24May2024_INFODT  \
# 0                                 NUPDRS1                           02/2011
# 1                                 NUPDRS1                           03/2012
# ...

# %%
test_df = pd.DataFrame({
    'first': ['Nafi', 'Lelouch', 'Walter'],
    'last': ['Nuru', 'Lamperouge', 'White'],
    'age': [21, 19, 50]
})
